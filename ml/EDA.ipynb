# %%
import json
import pandas as pd

# %%
df = pd.read_json("data/courses_plus.jsonl", lines=True)
df.head()
# Out:
#                                                  url  \
# 0          https://gb.ru/s/ai-integration-specialist
# 1            https://gb.ru/geek_university/developer
# 2  https://gb.ru/geek_university/developer/progra...
# 3  https://gb.ru/geek_university/developer/progra...
# 4  https://gb.ru/geek_university/developer/qa-eng...
#
#                                        title_preview  \
# 0  Специалист по внедрению Искусственного Интелле...
# 1  Разработчик: старт в ИТ с нуля до Junior\nИдеа...
# 2  Python-разработчик: быстрый старт в профессии\...
# 3  Программист с нуля до Junior\nВыберите професс...
# 4  Специалист по автоматизированному тестированию...
#
#                                  description_preview  duration_months  \
# 0  Лёгкий путь в Machine Learning и Data Science....                6
# 1  Идеальная программа для тех, кто хочет попасть...               12
# 2  Научитесь использовать язык программирования P...                9
# ...

# %%
df.payment_duration_months.value_counts()
# Out:
# payment_duration_months
# 36    94
# Name: count, dtype: int64

# %%
df.iloc[1].url
# Out:
# 'https://gb.ru/geek_university/management/accountant'

# %%
df.iloc[1].technologies
# Out:
# ['Инструменты',
#  '1С:Бухгалтерия 8, редакция\xa03.0',
#  '1С:зарплата и\xa0управление персоналом\xa08',
#  'Excel',
#  'Google Таблицы',
#  'Бухгалтерский баланс',
#  'Навыки',
#  'Работа с первичной бухгалтерий',
#  'Ведение бухучета и финансовых операций',
#  'Формирование бухгалтерской и\xa0налоговой отчетности',
#  'Подготовка иллюстрированной айдентики',
#  'Формирование бухгалтерских проводок',
#  'Взаимодействие с налоговой, фондами и\xa0контрагентами',
#  'Проведение инвентаризации, прохождение проверок',
#  'Учет основных и нематериальных активов',
#  'Организация документооборота',
#  'Знание законодательства']

# %%
df.url.tolist()
# Out:
# ['https://gb.ru/geek_university/developer/architecture/devops',
#  'https://gb.ru/geek_university/management/accountant',
#  'https://gb.ru/geek_university/marketing/seo',
#  'https://gb.ru/geek_university/marketing/digital/specialist',
#  'https://gb.ru/geek_university/developer/programmer/ai-spec',
#  'https://gb.ru/geek_university/multimedia/screenwriter-gb',
#  'https://gb.ru/geek_university/marketing/e-commerce',
#  'https://gb.ru/geek_university/design/graphic/master',
#  'https://gb.ru/geek_university/developer/qa-engineer/master',
#  'https://gb.ru/geek_university/marketing/smm-management-spec',
#  'https://gb.ru/geek_university/design/interface-spec',
#  'https://gb.ru/geek_university/design/concept-artist-gb',
#  'https://gb.ru/geek_university/design/digital/master',
#  'https://gb.ru/geek_university/developer/product-manager-gb',
#  'https://gb.ru/geek_university/developer/architecture/devops-spec-gb',
#  'https://gb.ru/geek_university/design/game-design-spec',
# ...

# %%
df[df.has_none_values == True]
# Out:
#                                                   url  \
# 13  https://gb.ru/geek_university/developer/produc...
# 17          https://gb.ru/s/ai-integration-specialist
# 28  https://gb.ru/geek_university/developer/projec...
# 41  https://gb.ru/geek_university/marketing/wildbe...
# 55  https://gb.ru/geek_university/developer/progra...
# 61  https://gb.ru/geek_university/developer/progra...
#
#                            title  price  \
# 13                          None   3479
# 17                          None   3599
# 28      Курс «Проджект-менеджер»   3479
# 41  Как продавать на Wildberries   1817
# 55                          None   4049
# 61                          None   4049
#
#                                           description  \
# 13  Именно продакт-менеджеры придумывают и запуска...
# 17                                               None
# 28                                               None
# 41  Курс для тех, кто хочет научиться получать мак...
# ...
